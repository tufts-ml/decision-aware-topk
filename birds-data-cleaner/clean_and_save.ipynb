# %%
import pandas as pd
import numpy as np
from asurv import read_asurv
from clean_and_save import points_to_boxes, create_task

# %%
"""
Choose from full aransas map (full map, 15036 boxes), medium (around 6700 boxes, with water cut), or small (1338 boxes; this size allows
our models to run on commodity GPUs)

= 'full' or = 'medium' will create a larger dataset but WILL NOT REPRODUCE RESULTS FROM THE PAPER; please keep it 
small if you want to reproduce results
"""

map_size = 'small'  # for running models

# %%
# do not change these
study = 'asurv'
temporal_res = '2monthly'
context_size = 5
box_length_m = 500
complete_idx_square = True
keep_geometry_col = False
save_shp_folder = False
years_through_2011 = 60

# %%
gdf = read_asurv(years_through_2011, temporal_res=temporal_res, context_size=context_size, map_size=map_size)
# Out:
# /cluster/XXXX-1/XXXX-2/XXXX-9/code/prob_diff_topk/birds-data-cleaner/asurv.py:279: FutureWarning: factorize with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   gdf[DATE_NAME_TRANSLATOR[temporal_res]] = pd.factorize(list(zip(gdf['season'], gdf[DATE_NAME_TRANSLATOR[temporal_res]])))[0] + 1
# /cluster/XXXX-1/XXXX-2/XXXX-9/code/prob_diff_topk/birds-data-cleaner/asurv.py:279: FutureWarning: factorize with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   gdf[DATE_NAME_TRANSLATOR[temporal_res]] = pd.factorize(list(zip(gdf['season'], gdf[DATE_NAME_TRANSLATOR[temporal_res]])))[0] + 1
# /cluster/XXXX-1/XXXX-2/XXXX-9/code/prob_diff_topk/birds-data-cleaner/asurv.py:279: FutureWarning: factorize with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
# ...

# %%
gdf = points_to_boxes(gdf, study=study, temporal_res=temporal_res, box_length_m=box_length_m, 
keep_geometry_col=keep_geometry_col, complete_idx_square=complete_idx_square, years_through_2011=years_through_2011, map_size=map_size, context_size=5)

create_task(gdf, study=study, start_year=1952, end_year=2011, timescale=temporal_res, box_length_m=box_length_m, 
season_clip_method='first_crane', lag_tsteps=1, context_size=context_size, geography_col='geoid', outcome_col='counts',
year_col='season_id_year', map_size=map_size)
# Out:
# unique counts for 1951-12-25_to_1952-02-28: [0. 1. 2. 4. 3. 6. 5.]
# unique counts for 1952-02-28_to_1952-04-30: [0. 2. 1. 3. 6.]
# unique counts for 1952-10-20_to_1952-12-25: [ 0.  1.  3.  2.  7.  6.  4.  5. 10.  8.]
# unique counts for 1952-12-25_to_1953-02-28: [0. 1. 4. 2. 6. 3.]
# unique counts for 1953-02-28_to_1953-04-30: [0. 3. 1. 5. 2. 4.]
# unique counts for 1953-10-20_to_1953-12-25: [0. 1. 2. 3. 6. 5. 7. 8.]
# unique counts for 1953-12-25_to_1954-02-28: [0. 1. 2. 3. 6. 9.]
# unique counts for 1954-02-28_to_1954-04-30: [0. 1. 3. 2. 6. 5.]
# unique counts for 1954-10-20_to_1954-12-25: [ 0.  4.  2.  1.  3.  6.  5.  7. 10. 11.  8.]
# unique counts for 1954-12-25_to_1955-02-28: [0. 2. 1. 4. 3.]
# unique counts for 1955-02-28_to_1955-04-30: [0. 3. 2. 1. 5.]
# unique counts for 1955-10-20_to_1955-12-25: [0. 3. 2. 4.]
# unique counts for 1955-12-25_to_1956-02-28: [0. 3. 1. 4.]
# unique counts for 1956-02-28_to_1956-04-30: [0. 3. 1. 2. 4.]
# ...
